# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
Micro_Retailer.info()
Micro_Retailer.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB
# (171, 106)

# %%
Micro_Retailer.dtypes
# Out:
# _record_id                                                     object
# _title                                                         object
# _server_updated_at                                             object
# _updated_by                                                    object
# _geometry                                                      object
# _latitude                                                     float64
# _longitude                                                    float64
# 228_store_name                                                 object
# 229_store_picture                                              object
# 232_type_of_store                                              object
# 108_does_the_micro_retailer_has_a_barred_window_               object
# 99_does_the_micro_retailer_exhibits_products_outside_          object
# 102_does_the_micro_retailer_sells_fresh_products_              object
# ...

# %%
#Imprimo los primeros 5 registro del dataframe
Micro_Retailer.head()
# Out:
#                              _record_id             _title  \
# 0  dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1  c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2  5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3  6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4  6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
#
#         _server_updated_at           _updated_by  \
# 0  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 3  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 4  2022-11-12 22:15:08 UTC  Salomon Abdala Perez
#
#                                        _geometry  _latitude  _longitude  \
# 0   SRID=4326;POINT(-98.233822273 19.0535362706)  19.053536  -98.233822
# 1  SRID=4326;POINT(-98.2341421351 19.0535610353)  19.053561  -98.234142
# 2    SRID=4326;POINT(-98.232299887 19.058654656)  19.058655  -98.232300
# ...

# %%
# Ajustar maximo de filas
pd.options.display.max_rows = None
# Ajustar maximo de columnas
pd.options.display.max_columns = None

# %%
#Identificar valores nulos por columna
valores_nulos=Micro_Retailer.isnull().sum()
valores_nulos
# Out:
# _record_id                                                      0
# _title                                                          0
# _server_updated_at                                              0
# _updated_by                                                     0
# _geometry                                                       0
# _latitude                                                       0
# _longitude                                                      0
# 228_store_name                                                  0
# 229_store_picture                                               0
# 232_type_of_store                                               0
# 108_does_the_micro_retailer_has_a_barred_window_                0
# 99_does_the_micro_retailer_exhibits_products_outside_           0
# 102_does_the_micro_retailer_sells_fresh_products_               0
# 97_number_of_customers_in_store                                 0
# ...

# %%
valores_nulos_dataframe=Micro_Retailer.isnull().sum().sum()
valores_nulos_dataframe
# Out:
# 9846

# %%
df=Micro_Retailer.copy()

# %%
dfsinnulos = df.fillna(method="ffill")
df1 = dfsinnulos.fillna(method="bfill")
# Out:
# /var/folders/b8/jg1xymvs3lsflq9qyj030f0m0000gp/T/ipykernel_8050/3901812563.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dfsinnulos = df.fillna(method="ffill")
# /var/folders/b8/jg1xymvs3lsflq9qyj030f0m0000gp/T/ipykernel_8050/3901812563.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1 = dfsinnulos.fillna(method="bfill")

# %%
valores_nulos_dataframe_total=df1.isnull().sum()
valores_nulos_dataframe_total
# Out:
# _record_id                                                      0
# _title                                                          0
# _server_updated_at                                              0
# _updated_by                                                     0
# _geometry                                                       0
# _latitude                                                       0
# _longitude                                                      0
# 228_store_name                                                  0
# 229_store_picture                                               0
# 232_type_of_store                                               0
# 108_does_the_micro_retailer_has_a_barred_window_                0
# 99_does_the_micro_retailer_exhibits_products_outside_           0
# 102_does_the_micro_retailer_sells_fresh_products_               0
# 97_number_of_customers_in_store                                 0
# ...

# %%
# Lista de los nombres de las 20 columnas que deseas seleccionar
columnas_seleccionadas = [
    '232_type_of_store', '184_store_devices', '210_sales_channels', '189_payment_methods', '214_customer_relationship_tools',
    '277_payment_method_suppliers', '49_inventory_records', '19_tax_id', '186_internet_connection', '5_change_store_space_last_year',
    '6_change_employees_average_salary_last_year', '20_reviews_finances_monthly', '18_sales_records', '193_sales_planning_tools', '227_agreement_ecommerce_platforms',
    '318_shopkeeper_name', '261_technology_organization', '254_technology_roadmap', '264_technology_budget', '312_payment_of_utilities'
]

# Selección de las columnas con loc
df_nuevo = df.loc[:, columnas_seleccionadas]
df_nuevo.head()
# Out:
#                 232_type_of_store  \
# 0                          Tailor
# 1  Grocery store (aka. nanostore)
# 2  Grocery store (aka. nanostore)
# 3  Grocery store (aka. nanostore)
# 4  Grocery store (aka. nanostore)
#
#                                    184_store_devices  \
# 0  POS system (i.e. computer + bar code scanner +...
# 1                     Dataphone (i.e. card payments)
# 2  Dataphone (i.e. card payments),POS system (i.e...
# 3  POS system (i.e. computer + bar code scanner +...
# 4                                         Smartphone
#
#                                   210_sales_channels  \
# 0  Llamada a Teléfono celular,Llamada a Teléfono ...
# 1                                           WhatsApp
# 2  Redes sociales (e.g. Facebook, Instagram),What...
# 3                            Llamada a Teléfono fijo
# 4                         Llamada a Teléfono celular
#
#                                  189_payment_methods  \
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(df_nuevo)
# Out:
#                    232_type_of_store  frequency  percentage  cumulative_perc
# 0     Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1    Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                     Dairy products         10    0.058480         0.543860
# 3                          Cafeteria          6    0.035088         0.578947
# 4                       Butcher shop          6    0.035088         0.614035
# 5      Produce (fruits & vegetables)          4    0.023392         0.637427
# 6                 Handmade products           2    0.011696         0.649123
# 7                         Papelería           2    0.011696         0.660819
# 8                           objetos           2    0.011696         0.672515
# 9                        Ferretería           2    0.011696         0.684211
# 10                        Lavanderia          1    0.005848         0.690058
# ...

# %%
df_nuevo.columns
# Out:
# Index(['232_type_of_store', '184_store_devices', '210_sales_channels',
#        '189_payment_methods', '214_customer_relationship_tools',
#        '277_payment_method_suppliers', '49_inventory_records', '19_tax_id',
#        '186_internet_connection', '5_change_store_space_last_year',
#        '6_change_employees_average_salary_last_year',
#        '20_reviews_finances_monthly', '18_sales_records',
#        '193_sales_planning_tools', '227_agreement_ecommerce_platforms',
#        '318_shopkeeper_name', '261_technology_organization',
#        '254_technology_roadmap', '264_technology_budget',
#        '312_payment_of_utilities'],
#       dtype='object')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df_nuevo['232_type_of_store'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1

#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('232_type_of_store')
Filtro_index1

#Elimino las columnas de "percentage" y "cumulative_perc"

Filtro_index_frequency1= Filtro_index1.drop(['percentage','cumulative_perc'], axis=1)
Filtro_index_frequency1

Filtro_index_frequency1.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de tipo de tienda")  # Agrega el título
plt.show()

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2= freq_tbl(df_nuevo['184_store_devices'])
table2
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table2[table2['frequency']>5]
Filtro2

#Ajusto el indice de mi dataframe
Filtro_index2= Filtro2.set_index('184_store_devices')
Filtro_index2

#Elimino las columnas de "percentage" y "cumulative_perc"

Filtro_index_frequency2= Filtro_index2.drop(['percentage','cumulative_perc'], axis=1)
Filtro_index_frequency2

Filtro_index_frequency2.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de tipo de artículo")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table3 = freq_tbl(df_nuevo['210_sales_channels'])
table3

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro3 = table3[table3['frequency'] > 5]
Filtro3

# Ajusto el índice de mi DataFrame
Filtro_index3 = Filtro3.set_index('210_sales_channels')
Filtro_index3

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency3 = Filtro_index3.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency3

# Graficar el gráfico de pastel
Filtro_index_frequency3.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de tipo canal de venta")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table5 = freq_tbl(df_nuevo['189_payment_methods'])
table5

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro5 = table5[table5['frequency'] > 5]
Filtro5

# Ajusto el índice de mi DataFrame
Filtro_index5 = Filtro5.set_index('189_payment_methods')
Filtro_index5

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency5 = Filtro_index5.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency5

# Graficar el gráfico de pastel
Filtro_index_frequency5.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de métodos de pago")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table6 = freq_tbl(df_nuevo['214_customer_relationship_tools'])
table6

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro6 = table6[table6['frequency'] > 5]
Filtro6

# Ajusto el índice de mi DataFrame
Filtro_index6 = Filtro6.set_index('214_customer_relationship_tools')
Filtro_index6

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency6 = Filtro_index6.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency6

# Graficar el gráfico de pastel
Filtro_index_frequency6.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de herramientas de relación con el cliente")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table7 = freq_tbl(df_nuevo['277_payment_method_suppliers'])
table7

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro7 = table7[table7['frequency'] > 5]
Filtro7

# Ajusto el índice de mi DataFrame
Filtro_index7 = Filtro7.set_index('277_payment_method_suppliers')
Filtro_index7

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency7 = Filtro_index7.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency7

# Graficar el gráfico de pastel
Filtro_index_frequency7.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de proveedores de métodos de pago")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table8 = freq_tbl(df_nuevo['49_inventory_records'])
table8

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro8 = table8[table8['frequency'] > 5]
Filtro8

# Ajusto el índice de mi DataFrame
Filtro_index8 = Filtro8.set_index('49_inventory_records')
Filtro_index8

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency8 = Filtro_index8.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency8

# Graficar el gráfico de pastel
Filtro_index_frequency8.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de registros de inventario")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table9 = freq_tbl(df_nuevo['19_tax_id'])
table9

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro9 = table9[table9['frequency'] > 5]
Filtro9

# Ajusto el índice de mi DataFrame
Filtro_index9 = Filtro9.set_index('19_tax_id')
Filtro_index9

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency9 = Filtro_index9.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency9

# Graficar el gráfico de pastel
Filtro_index_frequency9.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de identificaciones fiscales")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table10 = freq_tbl(df_nuevo['186_internet_connection'])
table10

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro10 = table10[table10['frequency'] > 5]
Filtro10

# Ajusto el índice de mi DataFrame
Filtro_index10 = Filtro10.set_index('186_internet_connection')
Filtro_index10

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency10 = Filtro_index10.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency10

# Graficar el gráfico de pastel
Filtro_index_frequency10.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de conexiones a internet")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table11 = freq_tbl(df_nuevo['5_change_store_space_last_year'])
table11

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro11 = table11[table11['frequency'] > 5]
Filtro11

# Ajusto el índice de mi DataFrame
Filtro_index11 = Filtro11.set_index('5_change_store_space_last_year')
Filtro_index11

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency11 = Filtro_index11.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency11

# Graficar el gráfico de pastel
Filtro_index_frequency11.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de cambios en el espacio de la tienda el año pasado")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table12 = freq_tbl(df_nuevo['6_change_employees_average_salary_last_year'])
table12

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro12 = table12[table12['frequency'] > 5]
Filtro12

# Ajusto el índice de mi DataFrame
Filtro_index12 = Filtro12.set_index('6_change_employees_average_salary_last_year')
Filtro_index12

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency12 = Filtro_index12.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency12

# Graficar el gráfico de pastel
Filtro_index_frequency12.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de cambios en el salario promedio de empleados el año pasado")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table13 = freq_tbl(df_nuevo['20_reviews_finances_monthly'])
table13

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro13 = table13[table13['frequency'] > 5]
Filtro13

# Ajusto el índice de mi DataFrame
Filtro_index13 = Filtro13.set_index('20_reviews_finances_monthly')
Filtro_index13

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency13 = Filtro_index13.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency13

# Graficar el gráfico de pastel
Filtro_index_frequency13.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de revisiones financieras mensuales")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table14 = freq_tbl(df_nuevo['18_sales_records'])
table14

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro14 = table14[table14['frequency'] > 5]
Filtro14

# Ajusto el índice de mi DataFrame
Filtro_index14 = Filtro14.set_index('18_sales_records')
Filtro_index14

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency14 = Filtro_index14.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency14

# Graficar el gráfico de pastel
Filtro_index_frequency14.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de registros de ventas")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table15 = freq_tbl(df_nuevo['193_sales_planning_tools'])
table15

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro15 = table15[table15['frequency'] > 5]
Filtro15

# Ajusto el índice de mi DataFrame
Filtro_index15 = Filtro15.set_index('193_sales_planning_tools')
Filtro_index15

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency15 = Filtro_index15.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency15

# Graficar el gráfico de pastel
Filtro_index_frequency15.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de herramientas de planificación de ventas")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table16 = freq_tbl(df_nuevo['227_agreement_ecommerce_platforms'])
table16

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro16 = table16[table16['frequency'] > 5]
Filtro16

# Ajusto el índice de mi DataFrame
Filtro_index16 = Filtro16.set_index('227_agreement_ecommerce_platforms')
Filtro_index16

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency16 = Filtro_index16.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency16

# Graficar el gráfico de pastel
Filtro_index_frequency16.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de acuerdos con plataformas de comercio electrónico")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table17 = freq_tbl(df_nuevo['318_shopkeeper_name'])
table17

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro17 = table17[table17['frequency'] > 1]
Filtro17

# Ajusto el índice de mi DataFrame
Filtro_index17 = Filtro17.set_index('318_shopkeeper_name')
Filtro_index17

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency17 = Filtro_index17.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency17

# Graficar el gráfico de pastel
Filtro_index_frequency17.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de nombres de dueños de tienda")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table18 = freq_tbl(df_nuevo['261_technology_organization'])
table18

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro18 = table18[table18['frequency'] > 5]
Filtro18

# Ajusto el índice de mi DataFrame
Filtro_index18 = Filtro18.set_index('261_technology_organization')
Filtro_index18

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency18 = Filtro_index18.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency18

# Graficar el gráfico de pastel
Filtro_index_frequency18.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de organización tecnológica")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table19 = freq_tbl(df_nuevo['254_technology_roadmap'])
table19

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro19 = table19[table19['frequency'] > 5]
Filtro19

# Ajusto el índice de mi DataFrame
Filtro_index19 = Filtro19.set_index('254_technology_roadmap')
Filtro_index19

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency19 = Filtro_index19.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency19

# Graficar el gráfico de pastel
Filtro_index_frequency19.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de hoja de ruta tecnológica")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table20 = freq_tbl(df_nuevo['264_technology_budget'])
table20

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro20 = table20[table20['frequency'] > 5]
Filtro20

# Ajusto el índice de mi DataFrame
Filtro_index20 = Filtro20.set_index('264_technology_budget')
Filtro_index20

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency20 = Filtro_index20.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency20

# Graficar el gráfico de pastel
Filtro_index_frequency20.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de presupuesto tecnológico")  # Agrega el título
plt.show()

# %%
# Obtengo un análisis univariado de una variable categórica en específico
table21 = freq_tbl(df_nuevo['312_payment_of_utilities'])
table21

# Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro21 = table21[table21['frequency'] > 5]
Filtro21

# Ajusto el índice de mi DataFrame
Filtro_index21 = Filtro21.set_index('312_payment_of_utilities')
Filtro_index21

# Elimino las columnas de "percentage" y "cumulative_perc"
Filtro_index_frequency21 = Filtro_index21.drop(['percentage', 'cumulative_perc'], axis=1)
Filtro_index_frequency21

# Graficar el gráfico de pastel
Filtro_index_frequency21.plot(kind='pie', y='frequency', figsize=(5,5))
plt.title("Frecuencia de pagos de servicios públicos")  # Agrega el título
plt.show()
